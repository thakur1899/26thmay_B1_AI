# %%
path = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
import pytesseract
from PIL import Image

# %%
pytesseract.pytesseract.tesseract_cmd = path

# %%
img = Image.open('captcha.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=268x188 at 0x27377AFEE10>

# %%
text = pytesseract.image_to_string(img)
print(text.split("\n"))
img
# Out:
# ['captcha 246', '', ' ', '\x0c']
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=268x188 at 0x27377AFEE10>

# %%
img1 = Image.open('Image.png')
text1 = pytesseract.image_to_string(img1)
print(text1.split("\n"))
img1
# Out:
# ['  ', '', '=pierress oles Shey', '', 'r Safe', '_Jotegekigiteene ON Saet aie', '', 'daandrew nabashassprincessrostoy', '', 'rince=', '', ' ', '\x0c']
# <PIL.PngImagePlugin.PngImageFile image mode=P size=327x154 at 0x27377CC4860>

# %%
img2 = Image.open('Puretext.png')
text2 = pytesseract.image_to_string(img2)
print(text2.split("\n"))
img2
# Out:
# ['PURE', 'TEXT', '\x0c']
# <PIL.PngImagePlugin.PngImageFile image mode=P size=183x275 at 0x27377CCD780>

# %%
img3 = Image.open('Text4.png')
text3 = pytesseract.image_to_string(img3)
print(text3.split("\n"))
img3
# Out:
# ['Feeling of', 'Beauty —', 'Light is', '', 'reflected off', '', 'a flower', '\x0c']
# <PIL.PngImagePlugin.PngImageFile image mode=P size=225x225 at 0x27377B35AC8>
